# %% [markdown]
# Make an ETL pipeline that loads from your `tickets.json` file

# %%
import os
import sys
import logging
import pandas as pd
from google.cloud import bigquery
from hashlib import md5
from typing import List
import json


# **** SETUP ****

# global variables for file system/ loading JSON file
JSON_DATA = "../data/tickets.json"
# project paths  
PROJECT_NAME = "abstract-flame-407818"
DATASET_NAME = "air_travel"


#schemas we will use for each table 

TABLE_METADATA = {
    'airlines': {
        'table_name': 'airlines',
        'schema': [
            # indexes are written if only named in the schema
            bigquery.SchemaField('airline_name', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airline_iata', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airline_icao', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airline_callsign', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airline_country', 'string', mode='REQUIRED'),
        ],
    },
    'airports': {
        'table_name': 'airports',
        'schema': [
            # indexes are written if only named in the schema
            bigquery.SchemaField('airport_name', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airport_city', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airport_country', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airport_iata', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airport_icao', 'string', mode='REQUIRED'),
        ],
    },
    'passengers': {
        'table_name': 'passengers',
        'schema': [
            # schema for passengers
            bigquery.SchemaField('pass_name', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_gender', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_birth_date', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_email', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_street', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_city', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_state', 'string', mode='REQUIRED'),
            bigquery.SchemaField('pass_zip', 'int64', mode='REQUIRED'),
            bigquery.SchemaField('start_date', 'string', mode='REQUIRED'),
            bigquery.SchemaField('end_date', 'string', mode='NULLABLE'),
            bigquery.SchemaField('UUID', 'string', mode='REQUIRED'),
        ],
    },
    'tickets': {
        'table_name': 'tickets',
        'schema': [
            # schema for tickets
            bigquery.SchemaField('eticket_num', 'string', mode='REQUIRED'),
            bigquery.SchemaField('confirmation', 'string', mode='REQUIRED'),
            bigquery.SchemaField('origin_name', 'string', mode='REQUIRED'),
            bigquery.SchemaField('dest_name', 'string', mode='NULLABLE'),
            bigquery.SchemaField('ticket_date', 'string', mode='REQUIRED'),
            bigquery.SchemaField('price', 'float', mode='REQUIRED'),
            bigquery.SchemaField('seat', 'string', mode='REQUIRED'),
            bigquery.SchemaField('airline_iata', 'string', mode='REQUIRED'),
            bigquery.SchemaField('origin_iata', 'string', mode='REQUIRED'),
            bigquery.SchemaField('UUID', 'string', mode='REQUIRED'),
        ],
    },
}

# setup logging and logger
logging.basicConfig(            # setting up the root logger
    format='[%(levelname)-5s][%(asctime)s][%(module)s:%(lineno)04d] : %(message)s',
    level=logging.INFO,
    stream=sys.stdout
)
logger: logging.Logger = logging.getLogger('root')      # alias the root logger as `logger`
logger.setLevel(logging.DEBUG)                          # programmatically reassign the logging level

# %% [markdown]
# Create dataset in bigquery

# %%
#establish dataset ID
dataset_id = f"{PROJECT_NAME}.{DATASET_NAME}"
client = bigquery.Client()

def create_dataset(client: bigquery.Client ,dataset_id: str, location: str = 'US') -> None:
    """create a bigquery dataset"""
    # create the dataset
    dataset = bigquery.Dataset(dataset_id)
    dataset.location = location
    dataset = client.create_dataset(dataset, exists_ok=True)
    logger.info(f"Created Air Travel dataset: {dataset.full_dataset_id}")
# Out:
# [DEBUG][2023-12-23 13:27:21,915][_default:0255] : Checking /Users/kairo/.creds/dsa-deb-sa.json for explicit credentials as part of auth process...
# [DEBUG][2023-12-23 13:27:21,917][_default:0255] : Checking /Users/kairo/.creds/dsa-deb-sa.json for explicit credentials as part of auth process...

# %% [markdown]
# Load tickets JSON into pandas dataframe

# %%
# Load JSON into pandas dataframe
df = pd.read_json('./data/tickets.json', lines=True)
def extract_columns(dataframe, column_name): 
        df_columns = dataframe[column_name].apply(pd.Series)
        df_columns = df_columns.rename(columns={col: column_name + '_' + col for col in df_columns.columns})
        extract_df = pd.concat([dataframe.drop([column_name], axis=1), df_columns], axis=1)
        return extract_df

airline_df = extract_columns(df, 'airline')
#df2 = extract_columns(df1, 'origin')
#df3 = extract_columns(df2, 'destination')
#final_df = extract_columns(df3, 'passenger')
display(airline_df)
# Out:
#           eticket_num confirmation ticket_date   price seat  status  \
# 0     498-938211-0795       ZVFDC4  2022-03-23  723.42  31I  active
# 1     482-850738-6048       IL5GUI  2022-03-23  765.18  29B  active
# 2     275-207321-8092       CYEFBC  2022-03-21  753.89  26I  active
# 3     246-793315-3102       ZNGPC2  2022-03-22  793.89  15A  active
# 4     091-128904-1226       MGSBD9  2022-03-24  820.25  17F  active
# ...               ...          ...         ...     ...  ...     ...
# 4091  030-327889-3270       MVIBWK  2022-03-24  600.37  23E  active
# 4092  513-551750-0628       WZZGGB  2022-03-21  583.41  24F  active
# 4093  118-106280-2530       WUD4KR  2022-03-22  203.45  17H  active
# 4094  961-278558-3018       VI5039  2022-03-21  554.59  18G  active
# 4095  009-921411-5270       CGPT53  2022-03-24  551.67  31A  active
#
#                                                  origin  \
# 0     {'name': 'Montreal / Pierre Elliott Trudeau In...
# 1     {'name': 'Longdongbao Airport', 'city': 'Guiya...
# 2     {'name': 'Licenciado Gustavo Díaz Ordaz Intern...
# 3     {'name': 'El Tepual Airport', 'city': 'Puerto ...
# 4     {'name': 'Baltimore/Washington International T...
# ...                                                 ...
# 4091  {'name': 'Don Mueang International Airport', '...
# 4092  {'name': 'Governador Aluízio Alves Internation...
# 4093  {'name': 'Taiyuan Wusu Airport', 'city': 'Taiy...
# 4094  {'name': 'San Carlos De Bariloche Airport', 'c...
# 4095  {'name': 'Mineralnyye Vody Airport', 'city': '...
#
#                                             destination  \
# 0     {'name': 'Chicago Midway International Airport...
# 1     {'name': 'Ninoy Aquino International Airport',...
# 2     {'name': 'Ibiza Airport', 'city': 'Ibiza', 'co...
# 3     {'name': 'Gdańsk Lech Wałęsa Airport', 'city':...
# 4     {'name': 'London Gatwick Airport', 'city': 'Lo...
# ...                                                 ...
# 4091                                               None
# 4092  {'name': 'Charles de Gaulle International Airp...
# 4093  {'name': 'Miami International Airport', 'city'...
# 4094  {'name': 'Hamad International Airport', 'city'...
# 4095  {'name': 'Naha Airport', 'city': 'Okinawa', 'c...
#
#                                               passenger  \
# 0     {'first_name': 'Robert', 'last_name': 'Brown',...
# 1     {'first_name': 'Laura', 'last_name': 'Kent', '...
# 2     {'first_name': 'Lisa', 'last_name': 'Tucker', ...
# 3     {'first_name': 'Matthew', 'last_name': 'Yates'...
# 4     {'first_name': 'Megan', 'last_name': 'Villanue...
# ...                                                 ...
# 4091  {'first_name': 'Janice', 'last_name': 'Zamora'...
# 4092  {'first_name': 'Lisa', 'last_name': 'Tucker', ...
# 4093  {'first_name': 'Janice', 'last_name': 'Zamora'...
# 4094  {'first_name': 'Corey', 'last_name': 'Cook', '...
# 4095  {'first_name': 'Corey', 'last_name': 'Cook', '...
#
#                 airline_name airline_iata airline_icao airline_callsign  \
# 0     China Eastern Airlines           MU          CES    CHINA EASTERN
# 1          Hawaiian Airlines           HA          HAL         HAWAIIAN
# 2                   Wizz Air           W6          WZZ         WIZZ AIR
# 3                    AirAsia           AK          AXM    ASIAN EXPRESS
# 4            Xiamen Airlines           MF          CXA       XIAMEN AIR
# ...                      ...          ...          ...              ...
# 4091         Hainan Airlines           HU          CHH           HAINAN
# 4092       Malaysia Airlines           MH          MAS        MALAYSIAN
# 4093       Frontier Airlines           F9          FFT  FRONTIER FLIGHT
# 4094         Royal Air Maroc           AT          RAM   ROYALAIR MAROC
# 4095       Malaysia Airlines           MH          MAS        MALAYSIAN
#
#      airline_country
# 0              China
# 1      United States
# 2            Hungary
# 3           Malaysia
# 4              China
# ...              ...
# 4091           China
# 4092        Malaysia
# 4093   United States
# 4094         Morocco
# 4095        Malaysia
#
# [4096 rows x 14 columns]

# %% [markdown]
# Load airports dimension table

# %%
def airlines_get_unique(df: pd.DataFrame) -> pd.DataFrame:
    """
    Returns a unique set of products from the tickets dataframe 

    Args:
        df (pd.DataFrame): tickets dataframe

    Returns:
        pd.DataFrame: return value. unique airline names 
    """
    logger.debug(f"getting unique names...")
    # group by unique columns and only select them
    cols = ['airline_name', 'airline_iata', 'airline_icao', 'airline_callsign', 'airline_country']
    df = df.groupby(cols).all()
    df = df.reset_index().loc[:, cols]
    return df
airline_df = airlines_get_unique(airline_df)
display(airline_df)
# Out:
# [DEBUG][2023-12-23 14:00:14,279][779889110:0011] : getting unique iatas...
#                airline_name airline_iata airline_icao   airline_callsign  \
# 0                Air Canada           AC          ACA         AIR CANADA
# 1                 Air China           CA          CCA          AIR CHINA
# 2                Air France           AF          AFR           AIRFRANS
# 3           Air New Zealand           NZ          ANZ        NEW ZEALAND
# 4                   AirAsia           AK          AXM      ASIAN EXPRESS
# 5           Alaska Airlines           AS          ASA               Inc.
# 6             Allegiant Air           G4          AAY          ALLEGIANT
# 7         American Airlines           AA          AAL           AMERICAN
# 8           British Airways           BA          BAW          SPEEDBIRD
# 9                  Cape Air           9K          KAP               CAIR
# 10   China Eastern Airlines           MU          CES      CHINA EASTERN
# 11  China Southern Airlines           CZ          CSN     CHINA SOUTHERN
# 12    China United Airlines           HR          CUA           LIANHANG
# 13          Delta Air Lines           DL          DAL              DELTA
# 14       Ethiopian Airlines           ET          ETH          ETHIOPIAN
# 15        Frontier Airlines           F9          FFT    FRONTIER FLIGHT
# 16          Hainan Airlines           HU          CHH             HAINAN
# 17        Hawaiian Airlines           HA          HAL           HAWAIIAN
# 18        Indonesia AirAsia           QZ          AWQ          WAGON AIR
# 19                 Jeju Air           7C          JJA           JEJU AIR
# 20          JetBlue Airways           B6          JBU            JETBLUE
# 21         Juneyao Airlines           HO          DKH   JUNEYAO AIRLINES
# 22        Malaysia Airlines           MH          MAS          MALAYSIAN
# 23          Maya Island Air           MW          MYD             MYLAND
# 24                  Nok Air           DD          NOK            NOK AIR
# 25                 Oman Air           WY          OMA           OMAN AIR
# 26      Philippine Airlines           PR          PAL         PHILIPPINE
# 27            Qatar Airways           QR          QTR             QATARI
# 28          Royal Air Maroc           AT          RAM     ROYALAIR MAROC
# 29              S7 Airlines           S7          SBI  SIBERIAN AIRLINES
# 30        Shandong Airlines           SC          CDG           SHANDONG
# 31        Shanghai Airlines           FM          CSH       SHANGHAI AIR
# 32        Shenzhen Airlines           ZH          CSZ       SHENZHEN AIR
# 33         Sichuan Airlines           3U          CSC           SI CHUAN
# 34         Skymark Airlines           BC          SKY            SKYMARK
# 35       Southwest Airlines           WN          SWA          SOUTHWEST
# 36          Spirit Airlines           NK          NKS       SPIRIT WINGS
# 37          Spring Airlines           9S          CQH         AIR SPRING
# 38            Sriwijaya Air           SJ          SJY          SRIWIJAYA
# 39             Thai AirAsia           FD          AIQ          THAI ASIA
# 40               Tropic Air           PM          TOS           TROPISER
# 41         Turkish Airlines           TK          THY            TURKAIR
# 42          United Airlines           UA          UAL             UNITED
# 43            Ural Airlines           U6          SVR     SVERDLOVSK AIR
# 44         Vietnam Airlines           VN          HVN  VIET NAM AIRLINES
# 45                Wings Air           IW          WON        WINGS ABADI
# 46                 Wizz Air           W6          WZZ           WIZZ AIR
# 47          Xiamen Airlines           MF          CXA         XIAMEN AIR
#
#       airline_country
# 0              Canada
# 1               China
# 2              France
# 3         New Zealand
# 4            Malaysia
# 5              ALASKA
# 6       United States
# 7       United States
# 8      United Kingdom
# 9       United States
# 10              China
# 11              China
# 12              China
# 13      United States
# 14           Ethiopia
# 15      United States
# 16              China
# 17      United States
# 18          Indonesia
# 19  Republic of Korea
# 20      United States
# 21              China
# 22           Malaysia
# 23             Belize
# 24           Thailand
# 25               Oman
# 26        Philippines
# 27              Qatar
# 28            Morocco
# 29             Russia
# 30              China
# 31              China
# 32              China
# 33              China
# 34              Japan
# 35      United States
# 36      United States
# 37              China
# 38          Indonesia
# 39           Thailand
# 40             Belize
# 41             Turkey
# 42      United States
# 43             Russia
# 44            Vietnam
# 45          Indonesia
# 46            Hungary
# 47              China

# %% [markdown]
# Load the airlines dataframe columns into a bigquery table

# %%
airline_table_name = f"{PROJECT_NAME}.{DATASET_NAME}.{TABLE_METADATA['airlines']['table_name']}"
airline_schema = schema=TABLE_METADATA['airlines']['schema']

def load_table(
    df: pd.DataFrame, 
    client: bigquery.Client, 
    table_name: str, 
    schema: List[bigquery.SchemaField], 
    create_disposition: str = 'CREATE_IF_NEEDED', 
    write_disposition: str = 'WRITE_TRUNCATE'
    ) -> None:
    """load dataframe into bigquery table

    Args:
        df (pd.DataFrame): dataframe to load
        client (bigquery.Client): bigquery client
        table_name (str): full table name including project and dataset id
        schema (List[bigquery.SchemaField]): table schema with data types
        create_disposition (str, optional): create table disposition. Defaults to 'CREATE_IF_NEEDED'.
        write_disposition (str, optional): overwrite table disposition. Defaults to 'WRITE_TRUNCATE'.
    """
    # *** run some checks ***
    # test table name to be full table name including project and dataset name. It must contain to dots
    assert len(table_name.split('.')) == 3, f"Table name must be a full bigquery table name including project and dataset id: '{table_name}'"
    # setup bigquery load job:
    #  create table if needed, replace rows, define the table schema
    job_config = bigquery.LoadJobConfig(
        create_disposition=create_disposition,
        write_disposition=write_disposition,
        schema=schema
    )
    logger.info(f"loading table: '{table_name}'")
    job = client.load_table_from_dataframe(df, destination=table_name, job_config=job_config)
    job.result()        # wait for the job to finish
    # get the resulting table
    table = client.get_table(table_name)
    logger.info(f"loaded {table.num_rows} rows into {table.full_table_id}")
load_table(airline_df, client, airline_table_name, airline_schema)
# Out:
# [INFO ][2023-12-23 14:00:28,397][4006487939:0032] : loading table: 'abstract-flame-407818.air_travel.airlines'
# [DEBUG][2023-12-23 14:00:28,403][connectionpool:0292] : Resetting dropped connection: bigquery.googleapis.com
# [DEBUG][2023-12-23 14:00:29,472][connectionpool:0546] : https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/abstract-flame-407818/jobs?uploadType=multipart HTTP/1.1" 200 1918
# [DEBUG][2023-12-23 14:00:29,654][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/2eab7de6-d2ce-4707-a1cf-86bc0daeeec5?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 14:00:29,655][retry:0233] : Retrying due to , sleeping 0.3s ...
# [DEBUG][2023-12-23 14:00:30,071][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/2eab7de6-d2ce-4707-a1cf-86bc0daeeec5?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 14:00:30,072][retry:0233] : Retrying due to , sleeping 0.5s ...
# [DEBUG][2023-12-23 14:00:30,673][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/2eab7de6-d2ce-4707-a1cf-86bc0daeeec5?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 14:00:30,674][retry:0233] : Retrying due to , sleeping 0.7s ...
# [DEBUG][2023-12-23 14:00:31,553][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/2eab7de6-d2ce-4707-a1cf-86bc0daeeec5?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 14:00:31,765][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/datasets/air_travel/tables/airlines?prettyPrint=false HTTP/1.1" 200 None
# [INFO ][2023-12-23 14:00:31,767][4006487939:0037] : loaded 48 rows into abstract-flame-407818:air_travel.airlines

# %% [markdown]
# Load airports columns from JSON file

# %%
airport_df = extract_columns(df, 'origin')
airport_df = airport_df.rename(columns={'origin_name': 'airport_name', 'origin_city': 'airport_city', 'origin_country': 'airport_country', 'origin_iata': 'airport_iata', 'origin_icao': 'airport_icao'})
display(airport_df)
# Out:
#           eticket_num confirmation ticket_date   price seat  status  \
# 0     498-938211-0795       ZVFDC4  2022-03-23  723.42  31I  active
# 1     482-850738-6048       IL5GUI  2022-03-23  765.18  29B  active
# 2     275-207321-8092       CYEFBC  2022-03-21  753.89  26I  active
# 3     246-793315-3102       ZNGPC2  2022-03-22  793.89  15A  active
# 4     091-128904-1226       MGSBD9  2022-03-24  820.25  17F  active
# ...               ...          ...         ...     ...  ...     ...
# 4091  030-327889-3270       MVIBWK  2022-03-24  600.37  23E  active
# 4092  513-551750-0628       WZZGGB  2022-03-21  583.41  24F  active
# 4093  118-106280-2530       WUD4KR  2022-03-22  203.45  17H  active
# 4094  961-278558-3018       VI5039  2022-03-21  554.59  18G  active
# 4095  009-921411-5270       CGPT53  2022-03-24  551.67  31A  active
#
#                                                 airline  \
# 0     {'name': 'China Eastern Airlines', 'iata': 'MU...
# 1     {'name': 'Hawaiian Airlines', 'iata': 'HA', 'i...
# 2     {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZ...
# 3     {'name': 'AirAsia', 'iata': 'AK', 'icao': 'AXM...
# 4     {'name': 'Xiamen Airlines', 'iata': 'MF', 'ica...
# ...                                                 ...
# 4091  {'name': 'Hainan Airlines', 'iata': 'HU', 'ica...
# 4092  {'name': 'Malaysia Airlines', 'iata': 'MH', 'i...
# 4093  {'name': 'Frontier Airlines', 'iata': 'F9', 'i...
# 4094  {'name': 'Royal Air Maroc', 'iata': 'AT', 'ica...
# 4095  {'name': 'Malaysia Airlines', 'iata': 'MH', 'i...
#
#                                             destination  \
# 0     {'name': 'Chicago Midway International Airport...
# 1     {'name': 'Ninoy Aquino International Airport',...
# 2     {'name': 'Ibiza Airport', 'city': 'Ibiza', 'co...
# 3     {'name': 'Gdańsk Lech Wałęsa Airport', 'city':...
# 4     {'name': 'London Gatwick Airport', 'city': 'Lo...
# ...                                                 ...
# 4091                                               None
# 4092  {'name': 'Charles de Gaulle International Airp...
# 4093  {'name': 'Miami International Airport', 'city'...
# 4094  {'name': 'Hamad International Airport', 'city'...
# 4095  {'name': 'Naha Airport', 'city': 'Okinawa', 'c...
#
#                                               passenger  \
# 0     {'first_name': 'Robert', 'last_name': 'Brown',...
# 1     {'first_name': 'Laura', 'last_name': 'Kent', '...
# 2     {'first_name': 'Lisa', 'last_name': 'Tucker', ...
# 3     {'first_name': 'Matthew', 'last_name': 'Yates'...
# 4     {'first_name': 'Megan', 'last_name': 'Villanue...
# ...                                                 ...
# 4091  {'first_name': 'Janice', 'last_name': 'Zamora'...
# 4092  {'first_name': 'Lisa', 'last_name': 'Tucker', ...
# 4093  {'first_name': 'Janice', 'last_name': 'Zamora'...
# 4094  {'first_name': 'Corey', 'last_name': 'Cook', '...
# 4095  {'first_name': 'Corey', 'last_name': 'Cook', '...
#
#                                            airport_name  \
# 0     Montreal / Pierre Elliott Trudeau Internationa...
# 1                                   Longdongbao Airport
# 2     Licenciado Gustavo Díaz Ordaz International Ai...
# 3                                     El Tepual Airport
# 4     Baltimore/Washington International Thurgood Ma...
# ...                                                 ...
# 4091                   Don Mueang International Airport
# 4092     Governador Aluízio Alves International Airport
# 4093                               Taiyuan Wusu Airport
# 4094                    San Carlos De Bariloche Airport
# 4095                           Mineralnyye Vody Airport
#
#                  airport_city airport_country airport_iata airport_icao  \
# 0                    Montreal          Canada          YUL         CYUL
# 1                     Guiyang           China          KWE         ZUGY
# 2             Puerto Vallarta          Mexico          PVR         MMPR
# 3                Puerto Montt           Chile          PMC         SCTE
# 4                   Baltimore   United States          BWI         KBWI
# ...                       ...             ...          ...          ...
# 4091                  Bangkok        Thailand          DMK         VTBD
# 4092                    Natal          Brazil          NAT         SBSG
# 4093                  Taiyuan           China          TYN         ZBYN
# 4094  San Carlos De Bariloche       Argentina          BRC         SAZS
# 4095          Mineralnye Vody          Russia          MRV         URMM
#
#       origin_latitude  origin_longitude  origin_altitude  \
# 0               45.47            -73.74            118.0
# 1               26.54            106.80           3736.0
# 2               20.68           -105.25             23.0
# 3              -41.44            -73.09            294.0
# 4               39.18            -76.67            146.0
# ...               ...               ...              ...
# 4091            13.91            100.61              9.0
# 4092            -5.77            -35.38            272.0
# 4093            37.75            112.63           2575.0
# 4094           -41.15            -71.16           2774.0
# 4095            44.23             43.08           1054.0
#
#            origin_tz_timezone
# 0             America/Toronto
# 1               Asia/Shanghai
# 2         America/Mexico_City
# 3            America/Santiago
# 4            America/New_York
# ...                       ...
# 4091             Asia/Bangkok
# 4092        America/Fortaleza
# 4093            Asia/Shanghai
# 4094  America/Argentina/Salta
# 4095            Europe/Moscow
#
# [4096 rows x 18 columns]

# %% [markdown]
# Find unique origin iatas for airports table

# %%
def airports_get_unique(df: pd.DataFrame) -> pd.DataFrame:

    logger.debug(f"getting unique names...")
    df = df[['airport_name', 'airport_city', 'airport_country', 'airport_iata', 'airport_icao']]
    df = df.drop_duplicates(subset='airport_iata', keep='first')
    return df 

airport_df = airports_get_unique(airport_df)
airport_df = airport_df.dropna(subset='airport_name')
airport_df = airport_df.reset_index()
airport_df = airport_df.drop(columns='index')
display(airport_df)
# Out:
# [DEBUG][2023-12-23 16:32:32,259][1318332233:0003] : getting unique names...
#                                           airport_name     airport_city  \
# 0    Montreal / Pierre Elliott Trudeau Internationa...         Montreal
# 1                                  Longdongbao Airport          Guiyang
# 2    Licenciado Gustavo Díaz Ordaz International Ai...  Puerto Vallarta
# 3                                    El Tepual Airport     Puerto Montt
# 4    Baltimore/Washington International Thurgood Ma...        Baltimore
# ..                                                 ...              ...
# 386                  Mactan Cebu International Airport             Cebu
# 387               Mariscal Sucre International Airport            Quito
# 388                    Capitan Oriel Lea Plaza Airport           Tarija
# 389                   Palm Beach International Airport  West Palm Beach
# 390                    Abu Dhabi International Airport        Abu Dhabi
#
#           airport_country airport_iata airport_icao
# 0                  Canada          YUL         CYUL
# 1                   China          KWE         ZUGY
# 2                  Mexico          PVR         MMPR
# 3                   Chile          PMC         SCTE
# 4           United States          BWI         KBWI
# ..                    ...          ...          ...
# 386           Philippines          CEB         RPVM
# 387               Ecuador          UIO         SEQM
# 388               Bolivia          TJA         SLTJ
# 389         United States          PBI         KPBI
# 390  United Arab Emirates          AUH         OMAA
#
# [391 rows x 5 columns]

# %% [markdown]
# Load airports dataframe into a bigquery table

# %%
airport_table_name = f"{PROJECT_NAME}.{DATASET_NAME}.{TABLE_METADATA['airports']['table_name']}"
airport_schema = schema=TABLE_METADATA['airports']['schema']

load_table(airport_df, client, airport_table_name, airport_schema)
# Out:
# [INFO ][2023-12-23 16:32:37,978][4006487939:0032] : loading table: 'abstract-flame-407818.air_travel.airports'
# [DEBUG][2023-12-23 16:32:38,943][connectionpool:0546] : https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/abstract-flame-407818/jobs?uploadType=multipart HTTP/1.1" 200 1914
# [DEBUG][2023-12-23 16:32:39,120][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/a3b79586-ad74-40da-bf30-c2321760d864?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 16:32:39,121][retry:0233] : Retrying due to , sleeping 0.3s ...
# [DEBUG][2023-12-23 16:32:39,580][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/a3b79586-ad74-40da-bf30-c2321760d864?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 16:32:39,581][retry:0233] : Retrying due to , sleeping 0.9s ...
# [DEBUG][2023-12-23 16:32:40,652][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/a3b79586-ad74-40da-bf30-c2321760d864?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 16:32:40,872][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/datasets/air_travel/tables/airports?prettyPrint=false HTTP/1.1" 200 None
# [INFO ][2023-12-23 16:32:40,873][4006487939:0037] : loaded 391 rows into abstract-flame-407818:air_travel.airports

# %% [markdown]
# Load passengers columns into dataframe

# %%
passenger_df = extract_columns(df, 'passenger')
display(passenger_df.head())
# Out:
#        eticket_num confirmation ticket_date   price seat  status  \
# 0  498-938211-0795       ZVFDC4  2022-03-23  723.42  31I  active
# 1  482-850738-6048       IL5GUI  2022-03-23  765.18  29B  active
# 2  275-207321-8092       CYEFBC  2022-03-21  753.89  26I  active
# 3  246-793315-3102       ZNGPC2  2022-03-22  793.89  15A  active
# 4  091-128904-1226       MGSBD9  2022-03-24  820.25  17F  active
#
#                                              airline  \
# 0  {'name': 'China Eastern Airlines', 'iata': 'MU...
# 1  {'name': 'Hawaiian Airlines', 'iata': 'HA', 'i...
# 2  {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZ...
# 3  {'name': 'AirAsia', 'iata': 'AK', 'icao': 'AXM...
# 4  {'name': 'Xiamen Airlines', 'iata': 'MF', 'ica...
#
#                                               origin  \
# 0  {'name': 'Montreal / Pierre Elliott Trudeau In...
# 1  {'name': 'Longdongbao Airport', 'city': 'Guiya...
# 2  {'name': 'Licenciado Gustavo Díaz Ordaz Intern...
# 3  {'name': 'El Tepual Airport', 'city': 'Puerto ...
# 4  {'name': 'Baltimore/Washington International T...
#
#                                          destination passenger_first_name  \
# 0  {'name': 'Chicago Midway International Airport...               Robert
# 1  {'name': 'Ninoy Aquino International Airport',...                Laura
# 2  {'name': 'Ibiza Airport', 'city': 'Ibiza', 'co...                 Lisa
# 3  {'name': 'Gdańsk Lech Wałęsa Airport', 'city':...              Matthew
# 4  {'name': 'London Gatwick Airport', 'city': 'Lo...                Megan
#
#   passenger_last_name passenger_gender passenger_birth_date  \
# 0               Brown                M           1969-02-17
# 1                Kent                F           1998-08-05
# 2              Tucker                F           1965-01-22
# 3               Yates               NB           1975-03-31
# 4          Villanueva               NB           1945-08-14
#
#                    passenger_email               passenger_street  \
# 0      robert.brown.69@hotmail.com                5007 Thomas Way
# 1        laura.kent.98@hotmail.com            13991 Davis Village
# 2       lisa.tucker.65@hotmail.com               04135 Marvin Via
# 3       matthew.yates.75@yahoo.com  76045 Samantha Road Suite 111
# 4  megan.villanueva.45@hotmail.com  848 Melissa Springs Suite 947
#
#            passenger_city passenger_state passenger_zip
# 0          Lake Hollystad              DC         20027
# 1  North Catherineborough              PA         16516
# 2        North Kristabury              MA         01093
# 3            Lake Jeffrey              DE         19898
# 4              Kellerstad              TX         76177

# %% [markdown]
# Concatenate first and last names of passengers and transform columns

# %%
def passenger_transform_and_unique(df: pd.DataFrame) -> pd.DataFrame:
    df = df.drop(columns= 'pass_name', errors='ignore')
    df['pass_name'] = df['passenger_first_name'] + ' ' + df['passenger_last_name']
    df = df.rename(columns={'passenger_gender': 'pass_gender',
                            'passenger_birth_date': 'pass_birth_date',
                            'passenger_email': 'pass_email',
                            'passenger_street': 'pass_street',
                            'passenger_city': 'pass_city',
                            'passenger_state': 'pass_state',
                            'passenger_zip': 'pass_zip',
                            'ticket_date': 'start_date'})
    df['end_date'] = None
    df = df[['pass_name', 'pass_gender', 'pass_birth_date', 'pass_email', 'pass_street', 'pass_city', 'pass_state', 'pass_zip', 'start_date', 'end_date']]
    df = df.drop_duplicates(subset='pass_name')
    df = df.reset_index()
    df = df.drop(columns='index')
    df = df.astype({'pass_zip': 'int64'})
    return df
passenger_df = passenger_transform_and_unique(passenger_df)
display(passenger_df)
# Out:
#               pass_name pass_gender pass_birth_date  \
# 0          Robert Brown           M      1969-02-17
# 1            Laura Kent           F      1998-08-05
# 2           Lisa Tucker           F      1965-01-22
# 3         Matthew Yates          NB      1975-03-31
# 4      Megan Villanueva          NB      1945-08-14
# 5            Sarah Hall          NB      1944-08-31
# 6         Seth Thompson           M      1968-05-02
# 7       Jennifer Garcia           F      1950-02-12
# 8           Becky Clark           F      1991-11-09
# 9           Ronald Cook           M      1976-07-29
# 10       Shannon Rhodes          NB      1978-10-09
# 11         Tony Hoffman          NB      2003-03-18
# 12        Cheryl Hughes          NB      1945-05-20
# 13   Danielle Henderson          NB      1970-08-11
# 14         Belinda Cook           F      1991-01-26
# 15          Sean Murray           M      1953-02-11
# 16          Kevin Moore           M      1979-04-11
# 17         Sarah Rivera           F      2004-02-26
# 18         Rachel Duffy          NB      1960-05-14
# 19           Corey Cook           M      1983-06-14
# 20          Carl Wilson           M      1980-04-24
# 21       Rebecca Wilson           F      1973-10-24
# 22  Christian Stevenson          NB      1993-06-14
# 23         Autumn Morse           F      1960-01-18
# 24          Laurie York           F      1984-04-28
# 25         Hannah Smith           F      1966-07-01
# 26       Timothy Santos           M      1986-01-07
# 27           Paul Baird           M      1991-10-21
# 28    Nicholas Phillips          NB      2000-04-23
# 29      Annette Hawkins           F      1943-07-11
# 30        Janice Zamora           F      2000-06-14
# 31        Julie Carlson           F      1977-04-05
#
#                             pass_email                        pass_street  \
# 0          robert.brown.69@hotmail.com                    5007 Thomas Way
# 1            laura.kent.98@hotmail.com                13991 Davis Village
# 2           lisa.tucker.65@hotmail.com                   04135 Marvin Via
# 3           matthew.yates.75@yahoo.com      76045 Samantha Road Suite 111
# 4      megan.villanueva.45@hotmail.com      848 Melissa Springs Suite 947
# 5              sarah.hall.44@gmail.com  75420 Michael Mountains Suite 485
# 6           seth.thompson.68@yahoo.com    22455 Higgins Junction Apt. 042
# 7         jennifer.garcia.50@gmail.com                  6607 Sharp Common
# 8             becky.clark.91@gmail.com                   691 Jones Cliffs
# 9           ronald.cook.76@hotmail.com                 93328 Davis Island
# 10         shannon.rhodes.78@gmail.com        3039 Daniel Mount Suite 582
# 11           tony.hoffman.03@gmail.com            4706 Amy Roads Apt. 206
# 12          cheryl.hughes.45@gmail.com       00992 Garcia Plaza Suite 367
# 13   danielle.henderson.70@hotmail.com        7389 Alec Squares Suite 508
# 14         belinda.cook.91@hotmail.com          1965 Kelly Field Apt. 094
# 15            sean.murray.53@yahoo.com          809 Erika Valley Apt. 634
# 16            kevin.moore.79@gmail.com                  8332 Watson Shore
# 17         sarah.rivera.04@hotmail.com          5938 Ramos Pike Suite 080
# 18         rachel.duffy.60@hotmail.com              18868 Dougherty Drive
# 19             corey.cook.83@gmail.com       9606 Barton Station Apt. 271
# 20          carl.wilson.80@hotmail.com                 2814 Houston Hills
# 21         rebecca.wilson.73@yahoo.com         24000 Erin Point Suite 590
# 22  christian.stevenson.93@hotmail.com                75945 Jennifer Loaf
# 23         autumn.morse.60@hotmail.com                  6984 Price Shoals
# 24            laurie.york.84@gmail.com                      248 Cook Park
# 25           hannah.smith.66@gmail.com                   230 Donna Street
# 26       timothy.santos.86@hotmail.com     64183 Kimberly Mills Suite 375
# 27           paul.baird.91@hotmail.com                   19344 Craig Walk
# 28    nicholas.phillips.00@hotmail.com                  80132 Kevin Trace
# 29        annette.hawkins.43@yahoo.com        361 Robinson Green Apt. 635
# 30          janice.zamora.00@gmail.com        4759 William Haven Apt. 194
# 31        julie.carlson.77@hotmail.com                 5792 Tammy Centers
#
#                  pass_city pass_state  pass_zip  start_date end_date
# 0           Lake Hollystad         DC     20027  2022-03-23     None
# 1   North Catherineborough         PA     16516  2022-03-23     None
# 2         North Kristabury         MA      1093  2022-03-21     None
# 3             Lake Jeffrey         DE     19898  2022-03-22     None
# 4               Kellerstad         TX     76177  2022-03-24     None
# 5             New Victoria         HI     96727  2022-03-23     None
# 6                New Keith         OR     97405  2022-03-23     None
# 7                 Chadstad         VA     22121  2022-03-22     None
# 8             Michaelburgh         TX     76003  2022-03-23     None
# 9            Rodriguezside         MD     21408  2022-03-23     None
# 10           New Tonyaberg         NM     88155  2022-03-24     None
# 11          Stewartborough         AZ     85030  2022-03-22     None
# 12      North Chelseamouth         CT      6315  2022-03-24     None
# 13           Port Jonathan         NM     87320  2022-03-21     None
# 14               Jonesberg         IL     60613  2022-03-21     None
# 15            Petersenfort         NY     13184  2022-03-21     None
# 16          Port Davidtown         DC     20026  2022-03-24     None
# 17           Lake Marytown         CT      6314  2022-03-24     None
# 18             Snowchester         OK     73022  2022-03-24     None
# 19         Jacquelinemouth         IN     47081  2022-03-21     None
# 20           Rodriguezside         IA     51971  2022-03-22     None
# 21             Josephmouth         DC     20028  2022-03-21     None
# 22               Pooleland         KY     40009  2022-03-21     None
# 23                Erictown         HI     96818  2022-03-21     None
# 24              Sherriport         TN     37845  2022-03-24     None
# 25         Lake Adrianstad         MN     56413  2022-03-23     None
# 26         North Rachelton         VT      5249  2022-03-24     None
# 27              Burtontown         NC     27568  2022-03-21     None
# 28             Riveraburgh         NJ      8640  2022-03-21     None
# 29          North Lynntown         NV     89825  2022-03-22     None
# 30              West Corey         KS     66153  2022-03-24     None
# 31           Port Fernando         MO     65169  2022-03-24     None

# %% [markdown]
# Generate UUIDs for each passenger

# %%
import uuid

def create_uuid(df):
    for _ in range(len(df.index)):
        df['UUID'] = df.apply(lambda _: uuid.uuid4(), axis=1)
        df = df.astype({'UUID': 'string'})
    return df

passenger_df = create_uuid(passenger_df)
display(passenger_df)
# Out:
#               pass_name pass_gender pass_birth_date  \
# 0          Robert Brown           M      1969-02-17
# 1            Laura Kent           F      1998-08-05
# 2           Lisa Tucker           F      1965-01-22
# 3         Matthew Yates          NB      1975-03-31
# 4      Megan Villanueva          NB      1945-08-14
# 5            Sarah Hall          NB      1944-08-31
# 6         Seth Thompson           M      1968-05-02
# 7       Jennifer Garcia           F      1950-02-12
# 8           Becky Clark           F      1991-11-09
# 9           Ronald Cook           M      1976-07-29
# 10       Shannon Rhodes          NB      1978-10-09
# 11         Tony Hoffman          NB      2003-03-18
# 12        Cheryl Hughes          NB      1945-05-20
# 13   Danielle Henderson          NB      1970-08-11
# 14         Belinda Cook           F      1991-01-26
# 15          Sean Murray           M      1953-02-11
# 16          Kevin Moore           M      1979-04-11
# 17         Sarah Rivera           F      2004-02-26
# 18         Rachel Duffy          NB      1960-05-14
# 19           Corey Cook           M      1983-06-14
# 20          Carl Wilson           M      1980-04-24
# 21       Rebecca Wilson           F      1973-10-24
# 22  Christian Stevenson          NB      1993-06-14
# 23         Autumn Morse           F      1960-01-18
# 24          Laurie York           F      1984-04-28
# 25         Hannah Smith           F      1966-07-01
# 26       Timothy Santos           M      1986-01-07
# 27           Paul Baird           M      1991-10-21
# 28    Nicholas Phillips          NB      2000-04-23
# 29      Annette Hawkins           F      1943-07-11
# 30        Janice Zamora           F      2000-06-14
# 31        Julie Carlson           F      1977-04-05
#
#                             pass_email                        pass_street  \
# 0          robert.brown.69@hotmail.com                    5007 Thomas Way
# 1            laura.kent.98@hotmail.com                13991 Davis Village
# 2           lisa.tucker.65@hotmail.com                   04135 Marvin Via
# 3           matthew.yates.75@yahoo.com      76045 Samantha Road Suite 111
# 4      megan.villanueva.45@hotmail.com      848 Melissa Springs Suite 947
# 5              sarah.hall.44@gmail.com  75420 Michael Mountains Suite 485
# 6           seth.thompson.68@yahoo.com    22455 Higgins Junction Apt. 042
# 7         jennifer.garcia.50@gmail.com                  6607 Sharp Common
# 8             becky.clark.91@gmail.com                   691 Jones Cliffs
# 9           ronald.cook.76@hotmail.com                 93328 Davis Island
# 10         shannon.rhodes.78@gmail.com        3039 Daniel Mount Suite 582
# 11           tony.hoffman.03@gmail.com            4706 Amy Roads Apt. 206
# 12          cheryl.hughes.45@gmail.com       00992 Garcia Plaza Suite 367
# 13   danielle.henderson.70@hotmail.com        7389 Alec Squares Suite 508
# 14         belinda.cook.91@hotmail.com          1965 Kelly Field Apt. 094
# 15            sean.murray.53@yahoo.com          809 Erika Valley Apt. 634
# 16            kevin.moore.79@gmail.com                  8332 Watson Shore
# 17         sarah.rivera.04@hotmail.com          5938 Ramos Pike Suite 080
# 18         rachel.duffy.60@hotmail.com              18868 Dougherty Drive
# 19             corey.cook.83@gmail.com       9606 Barton Station Apt. 271
# 20          carl.wilson.80@hotmail.com                 2814 Houston Hills
# 21         rebecca.wilson.73@yahoo.com         24000 Erin Point Suite 590
# 22  christian.stevenson.93@hotmail.com                75945 Jennifer Loaf
# 23         autumn.morse.60@hotmail.com                  6984 Price Shoals
# 24            laurie.york.84@gmail.com                      248 Cook Park
# 25           hannah.smith.66@gmail.com                   230 Donna Street
# 26       timothy.santos.86@hotmail.com     64183 Kimberly Mills Suite 375
# 27           paul.baird.91@hotmail.com                   19344 Craig Walk
# 28    nicholas.phillips.00@hotmail.com                  80132 Kevin Trace
# 29        annette.hawkins.43@yahoo.com        361 Robinson Green Apt. 635
# 30          janice.zamora.00@gmail.com        4759 William Haven Apt. 194
# 31        julie.carlson.77@hotmail.com                 5792 Tammy Centers
#
#                  pass_city pass_state  pass_zip  start_date end_date  \
# 0           Lake Hollystad         DC     20027  2022-03-23     None
# 1   North Catherineborough         PA     16516  2022-03-23     None
# 2         North Kristabury         MA      1093  2022-03-21     None
# 3             Lake Jeffrey         DE     19898  2022-03-22     None
# 4               Kellerstad         TX     76177  2022-03-24     None
# 5             New Victoria         HI     96727  2022-03-23     None
# 6                New Keith         OR     97405  2022-03-23     None
# 7                 Chadstad         VA     22121  2022-03-22     None
# 8             Michaelburgh         TX     76003  2022-03-23     None
# 9            Rodriguezside         MD     21408  2022-03-23     None
# 10           New Tonyaberg         NM     88155  2022-03-24     None
# 11          Stewartborough         AZ     85030  2022-03-22     None
# 12      North Chelseamouth         CT      6315  2022-03-24     None
# 13           Port Jonathan         NM     87320  2022-03-21     None
# 14               Jonesberg         IL     60613  2022-03-21     None
# 15            Petersenfort         NY     13184  2022-03-21     None
# 16          Port Davidtown         DC     20026  2022-03-24     None
# 17           Lake Marytown         CT      6314  2022-03-24     None
# 18             Snowchester         OK     73022  2022-03-24     None
# 19         Jacquelinemouth         IN     47081  2022-03-21     None
# 20           Rodriguezside         IA     51971  2022-03-22     None
# 21             Josephmouth         DC     20028  2022-03-21     None
# 22               Pooleland         KY     40009  2022-03-21     None
# 23                Erictown         HI     96818  2022-03-21     None
# 24              Sherriport         TN     37845  2022-03-24     None
# 25         Lake Adrianstad         MN     56413  2022-03-23     None
# 26         North Rachelton         VT      5249  2022-03-24     None
# 27              Burtontown         NC     27568  2022-03-21     None
# 28             Riveraburgh         NJ      8640  2022-03-21     None
# 29          North Lynntown         NV     89825  2022-03-22     None
# 30              West Corey         KS     66153  2022-03-24     None
# 31           Port Fernando         MO     65169  2022-03-24     None
#
#                                     UUID
# 0   bb7fa7ea-cc63-426f-b581-9d95b83f34b9
# 1   5883b402-a7c0-4015-87b9-4def1cf2f277
# 2   fced00a7-9db5-473c-a3a8-9a6f6990c017
# 3   447196f3-1b0d-48e3-a8dd-3febf0308408
# 4   a4df49c5-fd8c-49cb-8b57-0feb2e5bbaa2
# 5   681483b7-33a3-44d8-a699-ec3d346a1fc5
# 6   ca88034e-94d9-4490-9cc1-6e12a3e12e11
# 7   054d3470-50fb-4b56-98e9-c8c57425e4e4
# 8   e31a9386-9204-47d3-8ba8-8a518068db98
# 9   eac0646b-d1f4-4883-b577-9e641330a7f7
# 10  7550f826-b2e7-4479-a0ab-0e05be500dff
# 11  13f6b15c-5dc4-49f3-864b-e3a6fcff520a
# 12  81cbe174-145a-4681-a5a4-903144f7203f
# 13  05a12e7f-774b-4fc0-a059-544fff3c96c8
# 14  77c36efc-b1d7-4b0b-a5ac-aa669596b77f
# 15  c055f51e-b5a1-4b5c-8c2d-99ab93f204c0
# 16  af07fa1c-8c7d-4f49-8714-f37940007349
# 17  794897ea-5f63-4187-9d1d-bf05b4b0d966
# 18  dbcb525d-1ef0-41ae-8ebc-5907fb352ca0
# 19  e1d95cf5-6a12-4901-9752-d65c424f86e1
# 20  7d21c1d4-aa74-46b2-979a-26f77c80d831
# 21  19018fca-b4d4-4e5d-8984-8abce5b8320b
# 22  324eb4d9-39a7-4bd4-bd70-8dce41a2f310
# 23  20549ef2-88fb-479d-8202-55cc6ab0e9bb
# 24  3260cf1f-6ce3-41e2-8eef-a558ea67b199
# 25  dc89eaca-9e86-4ae0-8e09-3b9ce3f9c0c4
# 26  ca59d4c8-645f-4747-aef9-7b3be1f70619
# 27  6da02411-682e-4662-ad48-24aec978893d
# 28  7677734b-817f-4719-9555-220ac70f531f
# 29  bd6fe0cc-ad7b-498f-b3f4-ba53f2b4d387
# 30  aeefc804-9071-47ab-b6f1-1fa557ebb297
# 31  f71f1bee-106c-4261-a0b1-f7110b957332

# %% [markdown]
# load passengers columns into bigquery table

# %%
passenger_table_name = f"{PROJECT_NAME}.{DATASET_NAME}.{TABLE_METADATA['passengers']['table_name']}"
passenger_schema = schema=TABLE_METADATA['passengers']['schema']
load_table(passenger_df, client, passenger_table_name, passenger_schema)
# Out:
# [INFO ][2023-12-23 18:02:56,040][4006487939:0032] : loading table: 'abstract-flame-407818.air_travel.passengers'
# [DEBUG][2023-12-23 18:02:56,786][connectionpool:0546] : https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/abstract-flame-407818/jobs?uploadType=multipart HTTP/1.1" 200 2619
# [DEBUG][2023-12-23 18:02:56,951][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/96f5d1a4-be22-4186-8a90-17deb6892fd9?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 18:02:56,952][retry:0233] : Retrying due to , sleeping 0.6s ...
# [DEBUG][2023-12-23 18:02:57,662][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/96f5d1a4-be22-4186-8a90-17deb6892fd9?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 18:02:57,664][retry:0233] : Retrying due to , sleeping 0.5s ...
# [DEBUG][2023-12-23 18:02:58,318][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/96f5d1a4-be22-4186-8a90-17deb6892fd9?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 18:02:58,320][retry:0233] : Retrying due to , sleeping 0.8s ...
# [DEBUG][2023-12-23 18:02:59,273][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/96f5d1a4-be22-4186-8a90-17deb6892fd9?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 18:02:59,500][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/datasets/air_travel/tables/passengers?prettyPrint=false HTTP/1.1" 200 None
# [INFO ][2023-12-23 18:02:59,504][4006487939:0037] : loaded 32 rows into abstract-flame-407818:air_travel.passengers

# %% [markdown]
# Load tickets columns from ticket JSON into a pandas dataframe

# %%
ticket_df = extract_columns(df, 'passenger')
ticket_df = extract_columns(ticket_df, 'origin')
ticket_df = extract_columns(ticket_df, 'airline')
ticket_df = extract_columns(ticket_df, 'destination')
#ticket_df = ticket_df.rename(columns={'destination_name': 'dest_name'})
#ticket_df = ticket_df[['eticket_num', 'confirmation', 'origin_name', 'dest_name', 'ticket_date', 'price', 'seat', 'origin_iata', 'airline_iata', 'passenger_email']]
#ticket_df = ticket_df.dropna(subset='origin_name')
display(ticket_df)
# Out:
#           eticket_num confirmation ticket_date   price seat  status  \
# 0     498-938211-0795       ZVFDC4  2022-03-23  723.42  31I  active
# 1     482-850738-6048       IL5GUI  2022-03-23  765.18  29B  active
# 2     275-207321-8092       CYEFBC  2022-03-21  753.89  26I  active
# 3     246-793315-3102       ZNGPC2  2022-03-22  793.89  15A  active
# 4     091-128904-1226       MGSBD9  2022-03-24  820.25  17F  active
# ...               ...          ...         ...     ...  ...     ...
# 4091  030-327889-3270       MVIBWK  2022-03-24  600.37  23E  active
# 4092  513-551750-0628       WZZGGB  2022-03-21  583.41  24F  active
# 4093  118-106280-2530       WUD4KR  2022-03-22  203.45  17H  active
# 4094  961-278558-3018       VI5039  2022-03-21  554.59  18G  active
# 4095  009-921411-5270       CGPT53  2022-03-24  551.67  31A  active
#
#      passenger_first_name passenger_last_name passenger_gender  \
# 0                  Robert               Brown                M
# 1                   Laura                Kent                F
# 2                    Lisa              Tucker                F
# 3                 Matthew               Yates               NB
# 4                   Megan          Villanueva               NB
# ...                   ...                 ...              ...
# 4091               Janice              Zamora                F
# 4092                 Lisa              Tucker                F
# 4093               Janice              Zamora                F
# 4094                Corey                Cook                M
# 4095                Corey                Cook                M
#
#      passenger_birth_date  ... airline_country  \
# 0              1969-02-17  ...           China
# 1              1998-08-05  ...   United States
# 2              1965-01-22  ...         Hungary
# 3              1975-03-31  ...        Malaysia
# 4              1945-08-14  ...           China
# ...                   ...  ...             ...
# 4091           2000-06-14  ...           China
# 4092           1965-01-22  ...        Malaysia
# 4093           2000-06-14  ...   United States
# 4094           1983-06-14  ...         Morocco
# 4095           1983-06-14  ...        Malaysia
#
#                              destination_name destination_city  \
# 0        Chicago Midway International Airport          Chicago
# 1          Ninoy Aquino International Airport           Manila
# 2                               Ibiza Airport            Ibiza
# 3                  Gdańsk Lech Wałęsa Airport           Gdansk
# 4                      London Gatwick Airport           London
# ...                                       ...              ...
# 4091                                      NaN              NaN
# 4092  Charles de Gaulle International Airport            Paris
# 4093              Miami International Airport            Miami
# 4094              Hamad International Airport             Doha
# 4095                             Naha Airport          Okinawa
#
#      destination_country destination_iata destination_icao  \
# 0          United States              MDW             KMDW
# 1            Philippines              MNL             RPLL
# 2                  Spain              IBZ             LEIB
# 3                 Poland              GDN             EPGD
# 4         United Kingdom              LGW             EGKK
# ...                  ...              ...              ...
# 4091                 NaN              NaN              NaN
# 4092              France              CDG             LFPG
# 4093       United States              MIA             KMIA
# 4094               Qatar              DOH             OTHH
# 4095               Japan              OKA             ROAH
#
#      destination_latitude destination_longitude destination_altitude  \
# 0                   41.79                -87.75                620.0
# 1                   14.51                121.02                 75.0
# 2                   38.87                  1.37                 24.0
# 3                   54.38                 18.47                489.0
# 4                   51.15                 -0.19                202.0
# ...                   ...                   ...                  ...
# 4091                  NaN                   NaN                  NaN
# 4092                49.01                  2.55                392.0
# 4093                25.79                -80.29                  8.0
# 4094                25.27                 51.61                 13.0
# 4095                26.20                127.65                 12.0
#
#      destination_tz_timezone
# 0            America/Chicago
# 1                Asia/Manila
# 2              Europe/Madrid
# 3              Europe/Warsaw
# 4              Europe/London
# ...                      ...
# 4091                     NaN
# 4092            Europe/Paris
# 4093        America/New_York
# 4094                    None
# 4095              Asia/Tokyo
#
# [4096 rows x 38 columns]

# %% [markdown]
# slight transformations to the tickets dataframe

# %%
def transform_ticket(df: pd.DataFrame) -> pd.DataFrame:
    df = df.rename(columns={'destination_name': 'dest_name', 'passenger_email': 'pass_email'})
    df = df[['eticket_num', 'confirmation', 'origin_name', 'dest_name', 'ticket_date', 'price', 'seat', 'origin_iata', 'airline_iata', 'pass_email']]
    df = df.dropna(subset='origin_name')
    df = df.reset_index()
    df = df.drop(columns='index')
    return df
ticket_df = transform_ticket(ticket_df)
display(ticket_df.head())
# Out:
#        eticket_num confirmation  \
# 0  498-938211-0795       ZVFDC4
# 1  482-850738-6048       IL5GUI
# 2  275-207321-8092       CYEFBC
# 3  246-793315-3102       ZNGPC2
# 4  091-128904-1226       MGSBD9
#
#                                          origin_name  \
# 0  Montreal / Pierre Elliott Trudeau Internationa...
# 1                                Longdongbao Airport
# 2  Licenciado Gustavo Díaz Ordaz International Ai...
# 3                                  El Tepual Airport
# 4  Baltimore/Washington International Thurgood Ma...
#
#                               dest_name ticket_date   price seat origin_iata  \
# 0  Chicago Midway International Airport  2022-03-23  723.42  31I         YUL
# 1    Ninoy Aquino International Airport  2022-03-23  765.18  29B         KWE
# 2                         Ibiza Airport  2022-03-21  753.89  26I         PVR
# 3            Gdańsk Lech Wałęsa Airport  2022-03-22  793.89  15A         PMC
# 4                London Gatwick Airport  2022-03-24  820.25  17F         BWI
#
#   airline_iata                       pass_email
# 0           MU      robert.brown.69@hotmail.com
# 1           HA        laura.kent.98@hotmail.com
# 2           W6       lisa.tucker.65@hotmail.com
# 3           AK       matthew.yates.75@yahoo.com
# 4           MF  megan.villanueva.45@hotmail.com

# %% [markdown]
# Lookup UUIDs from passengers table and incorporate them into the tickets dataframe

# %%
def lookup_uuid(df: pd.DataFrame, client: bigquery.Client, passenger_table: str = 'passengers') -> pd.DataFrame:
    """
    Lookup UUID from passengers table.

    Args:
        df (pd.DataFrame): receipts dataframe
        client (bigquery.Client): bigquery client
        customer_table (str, optional): passengers table name. Defaults to 'customers'.

    Returns:
        pd.DataFrame: return dataframe
    """
    # passengers table query
    query = f"""
    SELECT
    UUID,
    pass_email
    FROM 
    `{PROJECT_NAME}.{DATASET_NAME}.passengers`
    """
    # query bigquery table into dataframe
    tdf = client.query(query).to_dataframe()
    # index by product_name for the join
    tdf = tdf.set_index(keys='pass_email')
    logger.info(f"query {len(tdf.index)} rows from passengers table")

    # drop UUID column if it already exists
    df = df.drop(columns=['UUID'], errors='ignore')

    logger.debug(f"preparing for join")

    # join with the main dataframe to get UUID
    df = df.join(tdf, on='pass_email', how='inner')
    logger.info(f"looked up UUID")
    # reset index
    df = df.reset_index()
    # drop index and pass_email columns
    df = df.drop(columns={'index', 'pass_email'})
    return df

ticket_df = lookup_uuid(ticket_df, client)
# Out:
# [DEBUG][2023-12-23 19:19:00,593][connectionpool:0546] : https://bigquery.googleapis.com:443 "POST /bigquery/v2/projects/abstract-flame-407818/jobs?prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:00,835][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/queries/466cffbf-7eb5-4d90-8a08-0bfe737a073e?maxResults=0&location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:01,016][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/queries/466cffbf-7eb5-4d90-8a08-0bfe737a073e?fields=jobReference%2CtotalRows%2CpageToken%2Crows&location=US&formatOptions.useInt64Timestamp=True&prettyPrint=false HTTP/1.1" 200 None
# [INFO ][2023-12-23 19:19:01,018][68093012:0025] : query 32 rows from passengers table
# [DEBUG][2023-12-23 19:19:01,019][68093012:0030] : preparing for join
# [INFO ][2023-12-23 19:19:01,021][68093012:0034] : looked up UUID

# %% [markdown]
# Load tickets columns into a bigquery table

# %%
ticket_table_name = f"{PROJECT_NAME}.{DATASET_NAME}.{TABLE_METADATA['tickets']['table_name']}"
ticket_schema = schema=TABLE_METADATA['tickets']['schema']
load_table(ticket_df, client, ticket_table_name, ticket_schema)
# Out:
# [INFO ][2023-12-23 19:19:48,501][4006487939:0032] : loading table: 'abstract-flame-407818.air_travel.tickets'
# [DEBUG][2023-12-23 19:19:49,348][connectionpool:0546] : https://bigquery.googleapis.com:443 "POST /upload/bigquery/v2/projects/abstract-flame-407818/jobs?uploadType=multipart HTTP/1.1" 200 2489
# [DEBUG][2023-12-23 19:19:49,506][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/f66a059f-31bb-4c6d-9400-f9a0d3720653?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:49,507][retry:0233] : Retrying due to , sleeping 0.6s ...
# [DEBUG][2023-12-23 19:19:50,225][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/f66a059f-31bb-4c6d-9400-f9a0d3720653?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:50,226][retry:0233] : Retrying due to , sleeping 0.4s ...
# [DEBUG][2023-12-23 19:19:50,794][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/f66a059f-31bb-4c6d-9400-f9a0d3720653?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:50,797][retry:0233] : Retrying due to , sleeping 0.2s ...
# [DEBUG][2023-12-23 19:19:51,337][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/jobs/f66a059f-31bb-4c6d-9400-f9a0d3720653?location=US&prettyPrint=false HTTP/1.1" 200 None
# [DEBUG][2023-12-23 19:19:51,554][connectionpool:0546] : https://bigquery.googleapis.com:443 "GET /bigquery/v2/projects/abstract-flame-407818/datasets/air_travel/tables/tickets?prettyPrint=false HTTP/1.1" 200 None
# [INFO ][2023-12-23 19:19:51,557][4006487939:0037] : loaded 4041 rows into abstract-flame-407818:air_travel.tickets

# %% [markdown]
# Added primary keys to the tables

# %%
ALTER TABLE `air_travel.airlines` ADD PRIMARY KEY (airline_iata) NOT ENFORCED;

ALTER TABLE `air_travel.airports` ADD PRIMARY KEY (airport_iata) NOT ENFORCED;

ALTER TABLE `air_travel.passengers` ADD PRIMARY KEY (UUID) NOT ENFORCED;

ALTER TABLE `air_travel.tickets` ADD PRIMARY KEY (eticket_num) NOT ENFORCED;
